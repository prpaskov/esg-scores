# %%
import os
current_directory = os.path.dirname(os.path.abspath("__file__"))
os.chdir(current_directory)
from scrape_10Ks import scrape_10K_filings
from predict_score import predictScore
from gen_and_viz_data import dataViz

# %%
#s10 = scrape_10K_filings(year_start = '2019', year_end = '2022')
dv = dataViz()
pred = predictScore()

# %% [markdown]
# ### Plots of Bloomberg ESG dataset (prior to preds)

# %%
dv.plot_scatter('Environmental', 'Social')

# %%
dv.plot_non_missing()

# %%
dv.plot_score_by_sector('Governance')
